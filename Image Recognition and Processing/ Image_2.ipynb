# %%
import cv2

img = cv2.imread("geeks.png")
img
# Out:
# array([[[ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         ...,
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14]],
#
#        [[ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         ...,
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14]],
#
#        [[ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         ...,
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14]],
#
#        ...,
#
#        [[ 72, 133,   9],
#         [ 72, 133,   9],
#         [ 72, 133,   9],
#         ...,
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14]],
#
#        [[ 72, 133,   9],
#         [ 72, 133,   9],
#         [ 72, 133,   9],
#         ...,
#         [ 87, 157,  14],
#         [ 87, 157,  14],
#         [ 87, 157,  14]],
#
#        [[ 72, 133,   9],
#         [ 72, 133,   9],
#         [ 72, 133,   9],
# ...

# %%
print(img.shape)
# Out:
# (225, 225, 3)

# %%
print(img)

# 225*225 pixels are there and every pixel is an array of 3 integers (Red, Green, Blue).
# Out:
# [[[ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]
#   ...
#   [ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]]
#
#  [[ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]
#   ...
#   [ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]]
#
#  [[ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]
#   ...
#   [ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]]
#
#  ...
#
#  [[ 72 133   9]
#   [ 72 133   9]
#   [ 72 133   9]
#   ...
#   [ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]]
#
#  [[ 72 133   9]
#   [ 72 133   9]
#   [ 72 133   9]
#   ...
#   [ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]]
#
#  [[ 72 133   9]
#   [ 72 133   9]
#   [ 72 133   9]
#   ...
#   [ 87 157  14]
#   [ 87 157  14]
#   [ 87 157  14]]]

# %%
# this is pixel of 0th row and 0th column
print(img[0][0])
# Out:
# [ 87 157  14]

# %%
from google.colab.patches import cv2_imshow

for i, row in enumerate(img):
  # get pixel value by iteration
  for j, pixel in enumerate(img):
    if(i==j or i+j == img.shape[0]):
      # update the pixel value to black
      img[i][j] = [0,0,0]

#display an image
cv2_imshow(img)
cv2.imwrite("output.png", img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
# True

# %%
imag = cv2.imread('grayscale.png',0)
imag

# shape prints the tuple (height,weight,channels)
print("image shape = ", imag.shape)

# img will be a numpy array of the above shape
print("\nimage array = ", imag)

print("\npixel at index (5,5): ", imag[5][5])
# Out:
# image shape =  (225, 225)
#
# image array =  [[106 106 106 ... 106 106 106]
#  [106 106 106 ... 106 106 106]
#  [106 106 106 ... 106 106 106]
#  ...
#  [ 88  88  88 ... 106 106 106]
#  [ 88  88  88 ... 106 106 106]
#  [ 88  88  88 ... 106 106 106]]
#
# pixel at index (5,5):  106
